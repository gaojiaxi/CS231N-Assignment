# %% [markdown]
# # Multiclass Support Vector Machine exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# In this exercise you will:
#
# - implement a fully-vectorized **loss function** for the SVM
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** using numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
# Run some setup code for this notebook.

import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# This is a bit of magic to make matplotlib figures appear inline in the
# notebook rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## CIFAR-10 Data Loading and Preprocessing

# %%
# Load the raw CIFAR-10 data.
cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

# As a sanity check, we print out the size of the training and test data.
print('Training data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Training data shape:  (50000, 32, 32, 3)
# Training labels shape:  (50000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %%
# Visualize some examples from the dataset.
# We show a few examples of training images from each class.
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 7
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(X_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
# Split the data into train, val, and test sets. In addition we will
# create a small development set as a subset of the training data;
# we can use this for development so our code runs faster.
num_training = 49000
num_validation = 1000
num_test = 1000
num_dev = 500

# Our validation set will be num_validation points from the original
# training set.
mask = range(num_training, num_training + num_validation)
X_val = X_train[mask]
y_val = y_train[mask]

# Our training set will be the first num_train points from the original
# training set.
mask = range(num_training)
X_train = X_train[mask]
y_train = y_train[mask]

# We will also make a development set, which is a small subset of
# the training set.
mask = np.random.choice(num_training, num_dev, replace=False)
X_dev = X_train[mask]
y_dev = y_train[mask]

# We use the first num_test points of the original test set as our
# test set.
mask = range(num_test)
X_test = X_test[mask]
y_test = y_test[mask]

print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 32, 32, 3)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 32, 32, 3)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 32, 32, 3)
# Test labels shape:  (1000,)

# %%
# Preprocessing: reshape the image data into rows
X_train = np.reshape(X_train, (X_train.shape[0], -1))
X_val = np.reshape(X_val, (X_val.shape[0], -1))
X_test = np.reshape(X_test, (X_test.shape[0], -1))
X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))

# As a sanity check, print out the shapes of the data
print('Training data shape: ', X_train.shape)
print('Validation data shape: ', X_val.shape)
print('Test data shape: ', X_test.shape)
print('dev data shape: ', X_dev.shape)
# Out:
# Training data shape:  (49000, 3072)
# Validation data shape:  (1000, 3072)
# Test data shape:  (1000, 3072)
# dev data shape:  (500, 3072)

# %%
# Preprocessing: subtract the mean image
# first: compute the image mean based on the training data
mean_image = np.mean(X_train, axis=0)
print(mean_image.shape)
print(mean_image[:10]) # print a few of the elements
plt.figure(figsize=(4,4))
plt.imshow(mean_image.reshape((32,32,3)).astype('uint8')) # visualize the mean image
plt.show()
# Out:
# (3072,)
# [ 130.64189796  135.98173469  132.47391837  130.05569388  135.34804082
#   131.75402041  130.96055102  136.14328571  132.47636735  131.48467347]

# %%
# second: subtract the mean image from train and test data
X_train -= mean_image
X_val -= mean_image
X_test -= mean_image
X_dev -= mean_image

# %%
# third: append the bias dimension of ones (i.e. bias trick) so that our SVM
# only has to worry about optimizing a single weight matrix W.
X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])

print(X_train.shape, X_val.shape, X_test.shape, X_dev.shape)
# Out:
# (49000, 3073) (1000, 3073) (1000, 3073) (500, 3073)

# %% [markdown]
# ## SVM Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/linear_svm.py**.
#
# As you can see, we have prefilled the function `compute_loss_naive` which uses for loops to evaluate the multiclass SVM loss function.

# %%
# Evaluate the naive implementation of the loss we provided for you:
from cs231n.classifiers.linear_svm import svm_loss_naive
import time

# generate a random SVM weight matrix of small numbers
W = np.random.randn(3073, 10) * 0.0001 

loss, grad = svm_loss_naive(W, X_dev, y_dev, 0.000005)
print('loss: %f' % (loss, ))
# Out:
# loss: 8.871087

# %% [markdown]
# The `grad` returned from the function above is right now all zero. Derive and implement the gradient for the SVM cost function and implement it inline inside the function `svm_loss_naive`. You will find it helpful to interleave your new code inside the existing function.
#
# To check that you have correctly implemented the gradient correctly, you can numerically estimate the gradient of the loss function and compare the numeric estimate to the gradient that you computed. We have provided code that does this for you:

# %%
# Once you've implemented the gradient, recompute it with the code below
# and gradient check it with the function we provided for you

# Compute the loss and its gradient at W.
loss, grad = svm_loss_naive(W, X_dev, y_dev, 0.0)

# Numerically compute the gradient along several randomly chosen dimensions, and
# compare them with your analytically computed gradient. The numbers should match
# almost exactly along all dimensions.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: svm_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad)

# do the gradient check once again with regularization turned on
# you didn't forget the regularization gradient did you?
loss, grad = svm_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: svm_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad)
# Out:
# numerical: -27.894235 analytic: -27.894235, relative error: 1.147936e-11
# numerical: 0.546433 analytic: 0.546433, relative error: 1.838555e-11
# numerical: 20.119229 analytic: 20.119229, relative error: 4.166476e-13
# numerical: -5.551621 analytic: -5.605887, relative error: 4.863674e-03
# numerical: -43.984606 analytic: -43.984606, relative error: 3.487805e-12
# numerical: 13.411157 analytic: 13.411157, relative error: 1.401227e-11
# numerical: -21.503903 analytic: -21.427725, relative error: 1.774402e-03
# numerical: 10.479425 analytic: 10.364429, relative error: 5.516995e-03
# numerical: 32.407626 analytic: 32.407626, relative error: 1.726158e-11
# numerical: 8.190519 analytic: 8.190519, relative error: 3.602978e-11
# numerical: -9.190429 analytic: -9.253576, relative error: 3.423681e-03
# numerical: 31.657848 analytic: 31.551823, relative error: 1.677361e-03
# numerical: -9.537881 analytic: -9.428522, relative error: 5.765934e-03
# numerical: -0.678359 analytic: -0.678359, relative error: 2.909015e-10
# numerical: 1.853311 analytic: 1.853311, relative error: 2.145127e-10
# numerical: 4.164572 analytic: 4.164572, relative error: 6.190781e-11
# numerical: 13.307472 analytic: 13.307472, relative error: 9.763476e-12
# numerical: -12.728575 analytic: -12.728575, relative error: 1.931624e-11
# numerical: 9.859840 analytic: 9.859840, relative error: 8.805450e-12
# numerical: 30.430583 analytic: 30.307821, relative error: 2.021156e-03

# %% [markdown]
# ### Inline Question 1:
# It is possible that once in a while a dimension in the gradcheck will not match exactly. What could such a discrepancy be caused by? Is it a reason for concern? What is a simple example in one dimension where a gradient check could fail? *Hint: the SVM loss function is not strictly speaking differentiable*
#
# **Your Answer:** *fill this in.*
# The loss function is not always differentiable as it may have some kink point if we plot it in one dimension.At that 'kink' point we have a lot subgradient and it may cause the failure of gradient check

# %%
# Next implement the function svm_loss_vectorized; for now only compute the loss;
# we will implement the gradient in a moment.
tic = time.time()
loss_naive, grad_naive = svm_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.linear_svm import svm_loss_vectorized
tic = time.time()
loss_vectorized, _ = svm_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# The losses should match but your vectorized implementation should be much faster.
print('difference: %f' % (loss_naive - loss_vectorized))
# Out:
# Naive loss: 8.871087e+00 computed in 0.062400s
# Vectorized loss: 8.871087e+00 computed in 0.015600s
# difference: -0.000000

# %%
# Complete the implementation of svm_loss_vectorized, and compute the gradient
# of the loss function in a vectorized way.

# The naive implementation and the vectorized implementation should match, but
# the vectorized version should still be much faster.
tic = time.time()
_, grad_naive = svm_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Naive loss and gradient: computed in %fs' % (toc - tic))

tic = time.time()
_, grad_vectorized = svm_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Vectorized loss and gradient: computed in %fs' % (toc - tic))

# The loss is a single number, so it is easy to compare the values computed
# by the two implementations. The gradient on the other hand is a matrix, so
# we use the Frobenius norm to compare them.
difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('difference: %f' % difference)
# Out:
# Naive loss and gradient: computed in 0.062400s
# Vectorized loss and gradient: computed in 0.000000s
# difference: 0.000000

# %% [markdown]
# ### Stochastic Gradient Descent
#
# We now have vectorized and efficient expressions for the loss, the gradient and our gradient matches the numerical gradient. We are therefore ready to do SGD to minimize the loss.

# %%
# In the file linear_classifier.py, implement SGD in the function
# LinearClassifier.train() and then run it with the code below.
from cs231n.classifiers import LinearSVM
svm = LinearSVM()
tic = time.time()
loss_hist = svm.train(X_train, y_train, learning_rate=1e-7, reg=2.5e4,
                      num_iters=1500, verbose=True)
toc = time.time()
print('That took %fs' % (toc - tic))
# Out:
# iteration 0 / 1500: loss 779.880796
# iteration 100 / 1500: loss 285.495624
# iteration 200 / 1500: loss 107.283017
# iteration 300 / 1500: loss 42.762719
# iteration 400 / 1500: loss 18.919380
# iteration 500 / 1500: loss 10.249536
# iteration 600 / 1500: loss 7.301671
# iteration 700 / 1500: loss 5.959827
# iteration 800 / 1500: loss 5.390529
# iteration 900 / 1500: loss 4.602308
# iteration 1000 / 1500: loss 5.038855
# iteration 1100 / 1500: loss 5.357278
# iteration 1200 / 1500: loss 5.134067
# iteration 1300 / 1500: loss 5.369872
# iteration 1400 / 1500: loss 4.984863
# That took 5.513200s

# %%
# A useful debugging strategy is to plot the loss as a function of
# iteration number:
plt.plot(loss_hist)
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %%
# Write the LinearSVM.predict function and evaluate the performance on both the
# training and validation set
y_train_pred = svm.predict(X_train)
print('training accuracy: %f' % (np.mean(y_train == y_train_pred), ))
y_val_pred = svm.predict(X_val)
print('validation accuracy: %f' % (np.mean(y_val == y_val_pred), ))
# Out:
# training accuracy: 0.366306
# validation accuracy: 0.371000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of about 0.4 on the validation set.
learning_rates = [1e-7, 5e-5]
regularization_strengths = [2.5e4, 5e4]

# results is dictionary mapping tuples of the form
# (learning_rate, regularization_strength) to tuples of the form
# (training_accuracy, validation_accuracy). The accuracy is simply the fraction
# of data points that are correctly classified.
results = {}
best_val = -1   # The highest validation accuracy that we have seen so far.
best_svm = None # The LinearSVM object that achieved the highest validation rate.

################################################################################
# TODO:                                                                        #
# Write code that chooses the best hyperparameters by tuning on the validation #
# set. For each combination of hyperparameters, train a linear SVM on the      #
# training set, compute its accuracy on the training and validation sets, and  #
# store these numbers in the results dictionary. In addition, store the best   #
# validation accuracy in best_val and the LinearSVM object that achieves this  #
# accuracy in best_svm.                                                        #
#                                                                              #
# Hint: You should use a small value for num_iters as you develop your         #
# validation code so that the SVMs don't take much time to train; once you are #
# confident that your validation code works, you should rerun the validation   #
# code with a larger value for num_iters.                                      #
################################################################################
pass
for lr in np.linspace(learning_rates[0], learning_rates[1], num=20):
    for reg in np.linspace(regularization_strengths[0], regularization_strengths[1], 20):
        svm = LinearSVM()
        svm.train(X_train, y_train, learning_rate=lr, reg=reg,
                      num_iters=1500, verbose=False)
        y_train_pred = svm.predict(X_train)
        train_accuracy=np.mean(y_train == y_train_pred)
        y_val_pred = svm.predict(X_val)
        valid_accuracy=np.mean(y_val == y_val_pred)
        results[(lr, reg)]=(train_accuracy,valid_accuracy)
        if valid_accuracy>best_val:
            best_val=valid_accuracy
            best_svm=svm
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# C:\Users\gaojiaxi\Desktop\cs231n_Gao\assignment1\cs231n\classifiers\linear_svm.py:87: RuntimeWarning: overflow encountered in double_scalars
#   loss += reg * np.sum(W * W)
# C:\Users\gaojiaxi\Desktop\cs231n_Gao\assignment1\cs231n\classifiers\linear_svm.py:87: RuntimeWarning: overflow encountered in multiply
#   loss += reg * np.sum(W * W)
# C:\Users\gaojiaxi\Desktop\cs231n_Gao\assignment1\cs231n\classifiers\linear_svm.py:81: RuntimeWarning: overflow encountered in subtract
#   margins = np.maximum(0, scores - true_class_score + 1.0)
# C:\Users\gaojiaxi\Desktop\cs231n_Gao\assignment1\cs231n\classifiers\linear_svm.py:109: RuntimeWarning: overflow encountered in multiply
#   dW += 2*reg*W
# C:\Users\gaojiaxi\Desktop\cs231n_Gao\assignment1\cs231n\classifiers\linear_svm.py:81: RuntimeWarning: invalid value encountered in subtract
#   margins = np.maximum(0, scores - true_class_score + 1.0)
# C:\Users\gaojiaxi\Desktop\cs231n_Gao\assignment1\cs231n\classifiers\linear_svm.py:81: RuntimeWarning: invalid value encountered in maximum
#   margins = np.maximum(0, scores - true_class_score + 1.0)
# C:\Users\gaojiaxi\Desktop\cs231n_Gao\assignment1\cs231n\classifiers\linear_svm.py:104: RuntimeWarning: invalid value encountered in greater
#   X_mask[margins>0]=1
# C:\Users\gaojiaxi\Desktop\cs231n_Gao\assignment1\cs231n\classifiers\linear_classifier.py:74: RuntimeWarning: invalid value encountered in subtract
#   self.W-=learning_rate*grad
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.371020 val accuracy: 0.390000
# lr 1.000000e-07 reg 2.631579e+04 train accuracy: 0.364061 val accuracy: 0.371000
# lr 1.000000e-07 reg 2.763158e+04 train accuracy: 0.367000 val accuracy: 0.378000
# lr 1.000000e-07 reg 2.894737e+04 train accuracy: 0.368041 val accuracy: 0.377000
# lr 1.000000e-07 reg 3.026316e+04 train accuracy: 0.364367 val accuracy: 0.369000
# lr 1.000000e-07 reg 3.157895e+04 train accuracy: 0.363510 val accuracy: 0.373000
# lr 1.000000e-07 reg 3.289474e+04 train accuracy: 0.367184 val accuracy: 0.370000
# lr 1.000000e-07 reg 3.421053e+04 train accuracy: 0.366000 val accuracy: 0.388000
# lr 1.000000e-07 reg 3.552632e+04 train accuracy: 0.366102 val accuracy: 0.376000
# lr 1.000000e-07 reg 3.684211e+04 train accuracy: 0.361592 val accuracy: 0.367000
# lr 1.000000e-07 reg 3.815789e+04 train accuracy: 0.352633 val accuracy: 0.362000
# lr 1.000000e-07 reg 3.947368e+04 train accuracy: 0.365837 val accuracy: 0.364000
# lr 1.000000e-07 reg 4.078947e+04 train accuracy: 0.354653 val accuracy: 0.361000
# lr 1.000000e-07 reg 4.210526e+04 train accuracy: 0.358898 val accuracy: 0.359000
# lr 1.000000e-07 reg 4.342105e+04 train accuracy: 0.357673 val accuracy: 0.376000
# lr 1.000000e-07 reg 4.473684e+04 train accuracy: 0.353755 val accuracy: 0.376000
# lr 1.000000e-07 reg 4.605263e+04 train accuracy: 0.358143 val accuracy: 0.371000
# lr 1.000000e-07 reg 4.736842e+04 train accuracy: 0.357939 val accuracy: 0.373000
# lr 1.000000e-07 reg 4.868421e+04 train accuracy: 0.361490 val accuracy: 0.362000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.356857 val accuracy: 0.367000
# lr 2.726316e-06 reg 2.500000e+04 train accuracy: 0.212653 val accuracy: 0.223000
# lr 2.726316e-06 reg 2.631579e+04 train accuracy: 0.255551 val accuracy: 0.262000
# lr 2.726316e-06 reg 2.763158e+04 train accuracy: 0.187571 val accuracy: 0.190000
# lr 2.726316e-06 reg 2.894737e+04 train accuracy: 0.223612 val accuracy: 0.250000
# lr 2.726316e-06 reg 3.026316e+04 train accuracy: 0.243980 val accuracy: 0.240000
# lr 2.726316e-06 reg 3.157895e+04 train accuracy: 0.211980 val accuracy: 0.207000
# lr 2.726316e-06 reg 3.289474e+04 train accuracy: 0.190020 val accuracy: 0.208000
# lr 2.726316e-06 reg 3.421053e+04 train accuracy: 0.201245 val accuracy: 0.204000
# lr 2.726316e-06 reg 3.552632e+04 train accuracy: 0.223184 val accuracy: 0.252000
# lr 2.726316e-06 reg 3.684211e+04 train accuracy: 0.242245 val accuracy: 0.250000
# lr 2.726316e-06 reg 3.815789e+04 train accuracy: 0.227265 val accuracy: 0.239000
# lr 2.726316e-06 reg 3.947368e+04 train accuracy: 0.233061 val accuracy: 0.249000
# lr 2.726316e-06 reg 4.078947e+04 train accuracy: 0.211204 val accuracy: 0.211000
# lr 2.726316e-06 reg 4.210526e+04 train accuracy: 0.201776 val accuracy: 0.197000
# lr 2.726316e-06 reg 4.342105e+04 train accuracy: 0.197735 val accuracy: 0.232000
# lr 2.726316e-06 reg 4.473684e+04 train accuracy: 0.207653 val accuracy: 0.205000
# lr 2.726316e-06 reg 4.605263e+04 train accuracy: 0.199551 val accuracy: 0.207000
# lr 2.726316e-06 reg 4.736842e+04 train accuracy: 0.210041 val accuracy: 0.195000
# lr 2.726316e-06 reg 4.868421e+04 train accuracy: 0.174796 val accuracy: 0.186000
# lr 2.726316e-06 reg 5.000000e+04 train accuracy: 0.203898 val accuracy: 0.215000
# lr 5.352632e-06 reg 2.500000e+04 train accuracy: 0.182429 val accuracy: 0.194000
# lr 5.352632e-06 reg 2.631579e+04 train accuracy: 0.204816 val accuracy: 0.219000
# lr 5.352632e-06 reg 2.763158e+04 train accuracy: 0.192265 val accuracy: 0.215000
# lr 5.352632e-06 reg 2.894737e+04 train accuracy: 0.180939 val accuracy: 0.178000
# lr 5.352632e-06 reg 3.026316e+04 train accuracy: 0.166796 val accuracy: 0.173000
# lr 5.352632e-06 reg 3.157895e+04 train accuracy: 0.175429 val accuracy: 0.173000
# lr 5.352632e-06 reg 3.289474e+04 train accuracy: 0.208041 val accuracy: 0.212000
# lr 5.352632e-06 reg 3.421053e+04 train accuracy: 0.176388 val accuracy: 0.162000
# lr 5.352632e-06 reg 3.552632e+04 train accuracy: 0.190265 val accuracy: 0.192000
# lr 5.352632e-06 reg 3.684211e+04 train accuracy: 0.203184 val accuracy: 0.200000
# lr 5.352632e-06 reg 3.815789e+04 train accuracy: 0.145796 val accuracy: 0.144000
# lr 5.352632e-06 reg 3.947368e+04 train accuracy: 0.172959 val accuracy: 0.171000
# lr 5.352632e-06 reg 4.078947e+04 train accuracy: 0.163367 val accuracy: 0.164000
# lr 5.352632e-06 reg 4.210526e+04 train accuracy: 0.175592 val accuracy: 0.178000
# lr 5.352632e-06 reg 4.342105e+04 train accuracy: 0.183612 val accuracy: 0.223000
# lr 5.352632e-06 reg 4.473684e+04 train accuracy: 0.184735 val accuracy: 0.194000
# lr 5.352632e-06 reg 4.605263e+04 train accuracy: 0.186755 val accuracy: 0.182000
# lr 5.352632e-06 reg 4.736842e+04 train accuracy: 0.188408 val accuracy: 0.215000
# lr 5.352632e-06 reg 4.868421e+04 train accuracy: 0.188469 val accuracy: 0.195000
# lr 5.352632e-06 reg 5.000000e+04 train accuracy: 0.171102 val accuracy: 0.158000
# lr 7.978947e-06 reg 2.500000e+04 train accuracy: 0.188653 val accuracy: 0.196000
# lr 7.978947e-06 reg 2.631579e+04 train accuracy: 0.164143 val accuracy: 0.168000
# lr 7.978947e-06 reg 2.763158e+04 train accuracy: 0.168163 val accuracy: 0.172000
# lr 7.978947e-06 reg 2.894737e+04 train accuracy: 0.201490 val accuracy: 0.216000
# lr 7.978947e-06 reg 3.026316e+04 train accuracy: 0.159776 val accuracy: 0.182000
# lr 7.978947e-06 reg 3.157895e+04 train accuracy: 0.150776 val accuracy: 0.137000
# lr 7.978947e-06 reg 3.289474e+04 train accuracy: 0.176796 val accuracy: 0.185000
# lr 7.978947e-06 reg 3.421053e+04 train accuracy: 0.179041 val accuracy: 0.190000
# lr 7.978947e-06 reg 3.552632e+04 train accuracy: 0.171857 val accuracy: 0.178000
# lr 7.978947e-06 reg 3.684211e+04 train accuracy: 0.166347 val accuracy: 0.159000
# lr 7.978947e-06 reg 3.815789e+04 train accuracy: 0.160653 val accuracy: 0.160000
# lr 7.978947e-06 reg 3.947368e+04 train accuracy: 0.160449 val accuracy: 0.148000
# lr 7.978947e-06 reg 4.078947e+04 train accuracy: 0.174020 val accuracy: 0.159000
# lr 7.978947e-06 reg 4.210526e+04 train accuracy: 0.133796 val accuracy: 0.118000
# lr 7.978947e-06 reg 4.342105e+04 train accuracy: 0.161184 val accuracy: 0.148000
# lr 7.978947e-06 reg 4.473684e+04 train accuracy: 0.176163 val accuracy: 0.168000
# lr 7.978947e-06 reg 4.605263e+04 train accuracy: 0.174673 val accuracy: 0.182000
# lr 7.978947e-06 reg 4.736842e+04 train accuracy: 0.159020 val accuracy: 0.188000
# lr 7.978947e-06 reg 4.868421e+04 train accuracy: 0.174224 val accuracy: 0.177000
# lr 7.978947e-06 reg 5.000000e+04 train accuracy: 0.126551 val accuracy: 0.135000
# lr 1.060526e-05 reg 2.500000e+04 train accuracy: 0.159082 val accuracy: 0.159000
# lr 1.060526e-05 reg 2.631579e+04 train accuracy: 0.164714 val accuracy: 0.179000
# lr 1.060526e-05 reg 2.763158e+04 train accuracy: 0.173816 val accuracy: 0.199000
# lr 1.060526e-05 reg 2.894737e+04 train accuracy: 0.167265 val accuracy: 0.167000
# lr 1.060526e-05 reg 3.026316e+04 train accuracy: 0.161918 val accuracy: 0.148000
# lr 1.060526e-05 reg 3.157895e+04 train accuracy: 0.153082 val accuracy: 0.168000
# lr 1.060526e-05 reg 3.289474e+04 train accuracy: 0.172714 val accuracy: 0.149000
# lr 1.060526e-05 reg 3.421053e+04 train accuracy: 0.169429 val accuracy: 0.177000
# lr 1.060526e-05 reg 3.552632e+04 train accuracy: 0.166755 val accuracy: 0.146000
# lr 1.060526e-05 reg 3.684211e+04 train accuracy: 0.175367 val accuracy: 0.168000
# lr 1.060526e-05 reg 3.815789e+04 train accuracy: 0.161551 val accuracy: 0.148000
# lr 1.060526e-05 reg 3.947368e+04 train accuracy: 0.192082 val accuracy: 0.186000
# lr 1.060526e-05 reg 4.078947e+04 train accuracy: 0.170367 val accuracy: 0.177000
# lr 1.060526e-05 reg 4.210526e+04 train accuracy: 0.162449 val accuracy: 0.160000
# lr 1.060526e-05 reg 4.342105e+04 train accuracy: 0.150122 val accuracy: 0.133000
# lr 1.060526e-05 reg 4.473684e+04 train accuracy: 0.181000 val accuracy: 0.183000
# lr 1.060526e-05 reg 4.605263e+04 train accuracy: 0.180755 val accuracy: 0.167000
# lr 1.060526e-05 reg 4.736842e+04 train accuracy: 0.180245 val accuracy: 0.190000
# lr 1.060526e-05 reg 4.868421e+04 train accuracy: 0.168163 val accuracy: 0.173000
# lr 1.060526e-05 reg 5.000000e+04 train accuracy: 0.160612 val accuracy: 0.180000
# lr 1.323158e-05 reg 2.500000e+04 train accuracy: 0.184755 val accuracy: 0.202000
# lr 1.323158e-05 reg 2.631579e+04 train accuracy: 0.133367 val accuracy: 0.127000
# lr 1.323158e-05 reg 2.763158e+04 train accuracy: 0.184327 val accuracy: 0.174000
# lr 1.323158e-05 reg 2.894737e+04 train accuracy: 0.157510 val accuracy: 0.160000
# lr 1.323158e-05 reg 3.026316e+04 train accuracy: 0.175959 val accuracy: 0.172000
# lr 1.323158e-05 reg 3.157895e+04 train accuracy: 0.141020 val accuracy: 0.161000
# lr 1.323158e-05 reg 3.289474e+04 train accuracy: 0.161306 val accuracy: 0.145000
# lr 1.323158e-05 reg 3.421053e+04 train accuracy: 0.167143 val accuracy: 0.165000
# lr 1.323158e-05 reg 3.552632e+04 train accuracy: 0.159265 val accuracy: 0.167000
# lr 1.323158e-05 reg 3.684211e+04 train accuracy: 0.151571 val accuracy: 0.142000
# lr 1.323158e-05 reg 3.815789e+04 train accuracy: 0.145184 val accuracy: 0.140000
# lr 1.323158e-05 reg 3.947368e+04 train accuracy: 0.171551 val accuracy: 0.178000
# lr 1.323158e-05 reg 4.078947e+04 train accuracy: 0.145082 val accuracy: 0.136000
# lr 1.323158e-05 reg 4.210526e+04 train accuracy: 0.164265 val accuracy: 0.144000
# lr 1.323158e-05 reg 4.342105e+04 train accuracy: 0.175449 val accuracy: 0.182000
# lr 1.323158e-05 reg 4.473684e+04 train accuracy: 0.163143 val accuracy: 0.173000
# lr 1.323158e-05 reg 4.605263e+04 train accuracy: 0.180367 val accuracy: 0.190000
# lr 1.323158e-05 reg 4.736842e+04 train accuracy: 0.120122 val accuracy: 0.120000
# lr 1.323158e-05 reg 4.868421e+04 train accuracy: 0.143592 val accuracy: 0.155000
# lr 1.323158e-05 reg 5.000000e+04 train accuracy: 0.107837 val accuracy: 0.142000
# lr 1.585789e-05 reg 2.500000e+04 train accuracy: 0.189898 val accuracy: 0.210000
# lr 1.585789e-05 reg 2.631579e+04 train accuracy: 0.159959 val accuracy: 0.157000
# lr 1.585789e-05 reg 2.763158e+04 train accuracy: 0.160898 val accuracy: 0.142000
# lr 1.585789e-05 reg 2.894737e+04 train accuracy: 0.169653 val accuracy: 0.173000
# lr 1.585789e-05 reg 3.026316e+04 train accuracy: 0.163735 val accuracy: 0.157000
# lr 1.585789e-05 reg 3.157895e+04 train accuracy: 0.150531 val accuracy: 0.134000
# lr 1.585789e-05 reg 3.289474e+04 train accuracy: 0.159327 val accuracy: 0.150000
# lr 1.585789e-05 reg 3.421053e+04 train accuracy: 0.179163 val accuracy: 0.191000
# lr 1.585789e-05 reg 3.552632e+04 train accuracy: 0.163857 val accuracy: 0.160000
# lr 1.585789e-05 reg 3.684211e+04 train accuracy: 0.172531 val accuracy: 0.166000
# lr 1.585789e-05 reg 3.815789e+04 train accuracy: 0.174000 val accuracy: 0.167000
# lr 1.585789e-05 reg 3.947368e+04 train accuracy: 0.166510 val accuracy: 0.144000
# lr 1.585789e-05 reg 4.078947e+04 train accuracy: 0.190776 val accuracy: 0.190000
# lr 1.585789e-05 reg 4.210526e+04 train accuracy: 0.140551 val accuracy: 0.157000
# lr 1.585789e-05 reg 4.342105e+04 train accuracy: 0.109837 val accuracy: 0.109000
# lr 1.585789e-05 reg 4.473684e+04 train accuracy: 0.134306 val accuracy: 0.119000
# lr 1.585789e-05 reg 4.605263e+04 train accuracy: 0.078898 val accuracy: 0.093000
# lr 1.585789e-05 reg 4.736842e+04 train accuracy: 0.132184 val accuracy: 0.110000
# lr 1.585789e-05 reg 4.868421e+04 train accuracy: 0.171122 val accuracy: 0.177000
# lr 1.585789e-05 reg 5.000000e+04 train accuracy: 0.169102 val accuracy: 0.170000
# lr 1.848421e-05 reg 2.500000e+04 train accuracy: 0.172286 val accuracy: 0.170000
# lr 1.848421e-05 reg 2.631579e+04 train accuracy: 0.156163 val accuracy: 0.148000
# lr 1.848421e-05 reg 2.763158e+04 train accuracy: 0.177898 val accuracy: 0.173000
# lr 1.848421e-05 reg 2.894737e+04 train accuracy: 0.161959 val accuracy: 0.147000
# lr 1.848421e-05 reg 3.026316e+04 train accuracy: 0.165694 val accuracy: 0.175000
# lr 1.848421e-05 reg 3.157895e+04 train accuracy: 0.159490 val accuracy: 0.145000
# lr 1.848421e-05 reg 3.289474e+04 train accuracy: 0.155367 val accuracy: 0.149000
# lr 1.848421e-05 reg 3.421053e+04 train accuracy: 0.150939 val accuracy: 0.151000
# lr 1.848421e-05 reg 3.552632e+04 train accuracy: 0.108429 val accuracy: 0.098000
# lr 1.848421e-05 reg 3.684211e+04 train accuracy: 0.156469 val accuracy: 0.160000
# lr 1.848421e-05 reg 3.815789e+04 train accuracy: 0.070367 val accuracy: 0.061000
# lr 1.848421e-05 reg 3.947368e+04 train accuracy: 0.155959 val accuracy: 0.169000
# lr 1.848421e-05 reg 4.078947e+04 train accuracy: 0.116245 val accuracy: 0.090000
# lr 1.848421e-05 reg 4.210526e+04 train accuracy: 0.106327 val accuracy: 0.101000
# lr 1.848421e-05 reg 4.342105e+04 train accuracy: 0.110082 val accuracy: 0.109000
# lr 1.848421e-05 reg 4.473684e+04 train accuracy: 0.063510 val accuracy: 0.052000
# lr 1.848421e-05 reg 4.605263e+04 train accuracy: 0.152347 val accuracy: 0.148000
# lr 1.848421e-05 reg 4.736842e+04 train accuracy: 0.107184 val accuracy: 0.113000
# lr 1.848421e-05 reg 4.868421e+04 train accuracy: 0.055857 val accuracy: 0.056000
# lr 1.848421e-05 reg 5.000000e+04 train accuracy: 0.096061 val accuracy: 0.091000
# lr 2.111053e-05 reg 2.500000e+04 train accuracy: 0.149327 val accuracy: 0.157000
# lr 2.111053e-05 reg 2.631579e+04 train accuracy: 0.123776 val accuracy: 0.117000
# lr 2.111053e-05 reg 2.763158e+04 train accuracy: 0.158612 val accuracy: 0.177000
# lr 2.111053e-05 reg 2.894737e+04 train accuracy: 0.148224 val accuracy: 0.155000
# lr 2.111053e-05 reg 3.026316e+04 train accuracy: 0.126245 val accuracy: 0.120000
# lr 2.111053e-05 reg 3.157895e+04 train accuracy: 0.150429 val accuracy: 0.164000
# lr 2.111053e-05 reg 3.289474e+04 train accuracy: 0.151673 val accuracy: 0.180000
# lr 2.111053e-05 reg 3.421053e+04 train accuracy: 0.090714 val accuracy: 0.093000
# lr 2.111053e-05 reg 3.552632e+04 train accuracy: 0.164000 val accuracy: 0.166000
# lr 2.111053e-05 reg 3.684211e+04 train accuracy: 0.128061 val accuracy: 0.133000
# lr 2.111053e-05 reg 3.815789e+04 train accuracy: 0.098041 val accuracy: 0.090000
# lr 2.111053e-05 reg 3.947368e+04 train accuracy: 0.061245 val accuracy: 0.065000
# lr 2.111053e-05 reg 4.078947e+04 train accuracy: 0.112816 val accuracy: 0.100000
# lr 2.111053e-05 reg 4.210526e+04 train accuracy: 0.070265 val accuracy: 0.073000
# lr 2.111053e-05 reg 4.342105e+04 train accuracy: 0.084551 val accuracy: 0.092000
# lr 2.111053e-05 reg 4.473684e+04 train accuracy: 0.052857 val accuracy: 0.044000
# lr 2.111053e-05 reg 4.605263e+04 train accuracy: 0.078000 val accuracy: 0.061000
# lr 2.111053e-05 reg 4.736842e+04 train accuracy: 0.092102 val accuracy: 0.086000
# lr 2.111053e-05 reg 4.868421e+04 train accuracy: 0.085184 val accuracy: 0.084000
# lr 2.111053e-05 reg 5.000000e+04 train accuracy: 0.096816 val accuracy: 0.089000
# lr 2.373684e-05 reg 2.500000e+04 train accuracy: 0.138306 val accuracy: 0.137000
# lr 2.373684e-05 reg 2.631579e+04 train accuracy: 0.154102 val accuracy: 0.175000
# lr 2.373684e-05 reg 2.763158e+04 train accuracy: 0.136694 val accuracy: 0.118000
# lr 2.373684e-05 reg 2.894737e+04 train accuracy: 0.183592 val accuracy: 0.184000
# lr 2.373684e-05 reg 3.026316e+04 train accuracy: 0.116735 val accuracy: 0.113000
# lr 2.373684e-05 reg 3.157895e+04 train accuracy: 0.158857 val accuracy: 0.172000
# lr 2.373684e-05 reg 3.289474e+04 train accuracy: 0.068184 val accuracy: 0.068000
# lr 2.373684e-05 reg 3.421053e+04 train accuracy: 0.065306 val accuracy: 0.051000
# lr 2.373684e-05 reg 3.552632e+04 train accuracy: 0.086122 val accuracy: 0.075000
# lr 2.373684e-05 reg 3.684211e+04 train accuracy: 0.053490 val accuracy: 0.048000
# lr 2.373684e-05 reg 3.815789e+04 train accuracy: 0.052286 val accuracy: 0.049000
# lr 2.373684e-05 reg 3.947368e+04 train accuracy: 0.069020 val accuracy: 0.061000
# lr 2.373684e-05 reg 4.078947e+04 train accuracy: 0.090939 val accuracy: 0.079000
# lr 2.373684e-05 reg 4.210526e+04 train accuracy: 0.111061 val accuracy: 0.127000
# lr 2.373684e-05 reg 4.342105e+04 train accuracy: 0.082347 val accuracy: 0.090000
# lr 2.373684e-05 reg 4.473684e+04 train accuracy: 0.055388 val accuracy: 0.047000
# lr 2.373684e-05 reg 4.605263e+04 train accuracy: 0.052469 val accuracy: 0.063000
# lr 2.373684e-05 reg 4.736842e+04 train accuracy: 0.056939 val accuracy: 0.064000
# lr 2.373684e-05 reg 4.868421e+04 train accuracy: 0.081429 val accuracy: 0.085000
# lr 2.373684e-05 reg 5.000000e+04 train accuracy: 0.078612 val accuracy: 0.076000
# lr 2.636316e-05 reg 2.500000e+04 train accuracy: 0.182184 val accuracy: 0.178000
# lr 2.636316e-05 reg 2.631579e+04 train accuracy: 0.149490 val accuracy: 0.142000
# lr 2.636316e-05 reg 2.763158e+04 train accuracy: 0.138959 val accuracy: 0.131000
# lr 2.636316e-05 reg 2.894737e+04 train accuracy: 0.112265 val accuracy: 0.110000
# lr 2.636316e-05 reg 3.026316e+04 train accuracy: 0.113286 val accuracy: 0.108000
# lr 2.636316e-05 reg 3.157895e+04 train accuracy: 0.073061 val accuracy: 0.071000
# lr 2.636316e-05 reg 3.289474e+04 train accuracy: 0.067694 val accuracy: 0.054000
# lr 2.636316e-05 reg 3.421053e+04 train accuracy: 0.113612 val accuracy: 0.110000
# lr 2.636316e-05 reg 3.552632e+04 train accuracy: 0.105245 val accuracy: 0.106000
# lr 2.636316e-05 reg 3.684211e+04 train accuracy: 0.101286 val accuracy: 0.082000
# lr 2.636316e-05 reg 3.815789e+04 train accuracy: 0.093571 val accuracy: 0.085000
# lr 2.636316e-05 reg 3.947368e+04 train accuracy: 0.056061 val accuracy: 0.064000
# lr 2.636316e-05 reg 4.078947e+04 train accuracy: 0.093224 val accuracy: 0.103000
# lr 2.636316e-05 reg 4.210526e+04 train accuracy: 0.059694 val accuracy: 0.062000
# lr 2.636316e-05 reg 4.342105e+04 train accuracy: 0.087571 val accuracy: 0.101000
# lr 2.636316e-05 reg 4.473684e+04 train accuracy: 0.095673 val accuracy: 0.084000
# lr 2.636316e-05 reg 4.605263e+04 train accuracy: 0.088061 val accuracy: 0.072000
# lr 2.636316e-05 reg 4.736842e+04 train accuracy: 0.050796 val accuracy: 0.042000
# lr 2.636316e-05 reg 4.868421e+04 train accuracy: 0.048755 val accuracy: 0.050000
# lr 2.636316e-05 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.898947e-05 reg 2.500000e+04 train accuracy: 0.158959 val accuracy: 0.170000
# lr 2.898947e-05 reg 2.631579e+04 train accuracy: 0.078143 val accuracy: 0.085000
# lr 2.898947e-05 reg 2.763158e+04 train accuracy: 0.174653 val accuracy: 0.166000
# lr 2.898947e-05 reg 2.894737e+04 train accuracy: 0.127898 val accuracy: 0.114000
# lr 2.898947e-05 reg 3.026316e+04 train accuracy: 0.088408 val accuracy: 0.092000
# lr 2.898947e-05 reg 3.157895e+04 train accuracy: 0.111143 val accuracy: 0.119000
# lr 2.898947e-05 reg 3.289474e+04 train accuracy: 0.095306 val accuracy: 0.098000
# lr 2.898947e-05 reg 3.421053e+04 train accuracy: 0.064224 val accuracy: 0.064000
# lr 2.898947e-05 reg 3.552632e+04 train accuracy: 0.073082 val accuracy: 0.064000
# lr 2.898947e-05 reg 3.684211e+04 train accuracy: 0.093755 val accuracy: 0.089000
# lr 2.898947e-05 reg 3.815789e+04 train accuracy: 0.059898 val accuracy: 0.063000
# lr 2.898947e-05 reg 3.947368e+04 train accuracy: 0.066592 val accuracy: 0.067000
# lr 2.898947e-05 reg 4.078947e+04 train accuracy: 0.045735 val accuracy: 0.041000
# lr 2.898947e-05 reg 4.210526e+04 train accuracy: 0.052184 val accuracy: 0.060000
# lr 2.898947e-05 reg 4.342105e+04 train accuracy: 0.056959 val accuracy: 0.077000
# lr 2.898947e-05 reg 4.473684e+04 train accuracy: 0.075918 val accuracy: 0.073000
# lr 2.898947e-05 reg 4.605263e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.898947e-05 reg 4.736842e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.898947e-05 reg 4.868421e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.898947e-05 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.161579e-05 reg 2.500000e+04 train accuracy: 0.122878 val accuracy: 0.120000
# lr 3.161579e-05 reg 2.631579e+04 train accuracy: 0.126673 val accuracy: 0.125000
# lr 3.161579e-05 reg 2.763158e+04 train accuracy: 0.055714 val accuracy: 0.051000
# lr 3.161579e-05 reg 2.894737e+04 train accuracy: 0.072286 val accuracy: 0.075000
# lr 3.161579e-05 reg 3.026316e+04 train accuracy: 0.052980 val accuracy: 0.048000
# lr 3.161579e-05 reg 3.157895e+04 train accuracy: 0.057122 val accuracy: 0.059000
# lr 3.161579e-05 reg 3.289474e+04 train accuracy: 0.062735 val accuracy: 0.048000
# lr 3.161579e-05 reg 3.421053e+04 train accuracy: 0.065327 val accuracy: 0.067000
# lr 3.161579e-05 reg 3.552632e+04 train accuracy: 0.046755 val accuracy: 0.046000
# lr 3.161579e-05 reg 3.684211e+04 train accuracy: 0.048531 val accuracy: 0.037000
# lr 3.161579e-05 reg 3.815789e+04 train accuracy: 0.049082 val accuracy: 0.048000
# lr 3.161579e-05 reg 3.947368e+04 train accuracy: 0.063469 val accuracy: 0.060000
# lr 3.161579e-05 reg 4.078947e+04 train accuracy: 0.060041 val accuracy: 0.055000
# lr 3.161579e-05 reg 4.210526e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.161579e-05 reg 4.342105e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.161579e-05 reg 4.473684e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.161579e-05 reg 4.605263e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.161579e-05 reg 4.736842e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.161579e-05 reg 4.868421e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.161579e-05 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.424211e-05 reg 2.500000e+04 train accuracy: 0.056653 val accuracy: 0.053000
# lr 3.424211e-05 reg 2.631579e+04 train accuracy: 0.060184 val accuracy: 0.058000
# lr 3.424211e-05 reg 2.763158e+04 train accuracy: 0.107122 val accuracy: 0.106000
# lr 3.424211e-05 reg 2.894737e+04 train accuracy: 0.051408 val accuracy: 0.048000
# lr 3.424211e-05 reg 3.026316e+04 train accuracy: 0.065082 val accuracy: 0.084000
# lr 3.424211e-05 reg 3.157895e+04 train accuracy: 0.076306 val accuracy: 0.078000
# lr 3.424211e-05 reg 3.289474e+04 train accuracy: 0.076061 val accuracy: 0.072000
# lr 3.424211e-05 reg 3.421053e+04 train accuracy: 0.059551 val accuracy: 0.064000
# lr 3.424211e-05 reg 3.552632e+04 train accuracy: 0.064673 val accuracy: 0.066000
# lr 3.424211e-05 reg 3.684211e+04 train accuracy: 0.087571 val accuracy: 0.088000
# lr 3.424211e-05 reg 3.815789e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.424211e-05 reg 3.947368e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.424211e-05 reg 4.078947e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.424211e-05 reg 4.210526e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.424211e-05 reg 4.342105e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.424211e-05 reg 4.473684e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.424211e-05 reg 4.605263e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.424211e-05 reg 4.736842e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.424211e-05 reg 4.868421e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.424211e-05 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.686842e-05 reg 2.500000e+04 train accuracy: 0.136878 val accuracy: 0.129000
# lr 3.686842e-05 reg 2.631579e+04 train accuracy: 0.056367 val accuracy: 0.053000
# lr 3.686842e-05 reg 2.763158e+04 train accuracy: 0.071143 val accuracy: 0.063000
# lr 3.686842e-05 reg 2.894737e+04 train accuracy: 0.053694 val accuracy: 0.048000
# lr 3.686842e-05 reg 3.026316e+04 train accuracy: 0.061939 val accuracy: 0.055000
# lr 3.686842e-05 reg 3.157895e+04 train accuracy: 0.050000 val accuracy: 0.054000
# lr 3.686842e-05 reg 3.289474e+04 train accuracy: 0.049857 val accuracy: 0.042000
# lr 3.686842e-05 reg 3.421053e+04 train accuracy: 0.059102 val accuracy: 0.061000
# lr 3.686842e-05 reg 3.552632e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.686842e-05 reg 3.684211e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.686842e-05 reg 3.815789e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.686842e-05 reg 3.947368e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.686842e-05 reg 4.078947e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.686842e-05 reg 4.210526e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.686842e-05 reg 4.342105e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.686842e-05 reg 4.473684e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.686842e-05 reg 4.605263e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.686842e-05 reg 4.736842e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.686842e-05 reg 4.868421e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.686842e-05 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.949474e-05 reg 2.500000e+04 train accuracy: 0.160510 val accuracy: 0.169000
# lr 3.949474e-05 reg 2.631579e+04 train accuracy: 0.061592 val accuracy: 0.044000
# lr 3.949474e-05 reg 2.763158e+04 train accuracy: 0.041898 val accuracy: 0.040000
# lr 3.949474e-05 reg 2.894737e+04 train accuracy: 0.075816 val accuracy: 0.081000
# lr 3.949474e-05 reg 3.026316e+04 train accuracy: 0.046959 val accuracy: 0.045000
# lr 3.949474e-05 reg 3.157895e+04 train accuracy: 0.063735 val accuracy: 0.058000
# lr 3.949474e-05 reg 3.289474e+04 train accuracy: 0.048714 val accuracy: 0.045000
# lr 3.949474e-05 reg 3.421053e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.949474e-05 reg 3.552632e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.949474e-05 reg 3.684211e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.949474e-05 reg 3.815789e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.949474e-05 reg 3.947368e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.949474e-05 reg 4.078947e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.949474e-05 reg 4.210526e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.949474e-05 reg 4.342105e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.949474e-05 reg 4.473684e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.949474e-05 reg 4.605263e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.949474e-05 reg 4.736842e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.949474e-05 reg 4.868421e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.949474e-05 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.212105e-05 reg 2.500000e+04 train accuracy: 0.050857 val accuracy: 0.047000
# lr 4.212105e-05 reg 2.631579e+04 train accuracy: 0.063224 val accuracy: 0.057000
# lr 4.212105e-05 reg 2.763158e+04 train accuracy: 0.053347 val accuracy: 0.056000
# lr 4.212105e-05 reg 2.894737e+04 train accuracy: 0.053184 val accuracy: 0.047000
# lr 4.212105e-05 reg 3.026316e+04 train accuracy: 0.070816 val accuracy: 0.069000
# lr 4.212105e-05 reg 3.157895e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.212105e-05 reg 3.289474e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.212105e-05 reg 3.421053e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.212105e-05 reg 3.552632e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.212105e-05 reg 3.684211e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.212105e-05 reg 3.815789e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.212105e-05 reg 3.947368e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.212105e-05 reg 4.078947e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.212105e-05 reg 4.210526e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.212105e-05 reg 4.342105e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.212105e-05 reg 4.473684e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.212105e-05 reg 4.605263e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.212105e-05 reg 4.736842e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.212105e-05 reg 4.868421e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.212105e-05 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 2.500000e+04 train accuracy: 0.047816 val accuracy: 0.045000
# lr 4.474737e-05 reg 2.631579e+04 train accuracy: 0.061653 val accuracy: 0.063000
# lr 4.474737e-05 reg 2.763158e+04 train accuracy: 0.088939 val accuracy: 0.087000
# lr 4.474737e-05 reg 2.894737e+04 train accuracy: 0.066959 val accuracy: 0.054000
# lr 4.474737e-05 reg 3.026316e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 3.157895e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 3.289474e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 3.421053e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 3.552632e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 3.684211e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 3.815789e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 3.947368e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 4.078947e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 4.210526e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 4.342105e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 4.473684e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 4.605263e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 4.736842e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 4.868421e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.474737e-05 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 2.500000e+04 train accuracy: 0.054388 val accuracy: 0.053000
# lr 4.737368e-05 reg 2.631579e+04 train accuracy: 0.093469 val accuracy: 0.095000
# lr 4.737368e-05 reg 2.763158e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 2.894737e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 3.026316e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 3.157895e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 3.289474e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 3.421053e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 3.552632e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 3.684211e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 3.815789e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 3.947368e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 4.078947e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 4.210526e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 4.342105e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 4.473684e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 4.605263e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 4.736842e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 4.868421e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.737368e-05 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 2.500000e+04 train accuracy: 0.061510 val accuracy: 0.076000
# lr 5.000000e-05 reg 2.631579e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 2.763158e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 2.894737e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 3.026316e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 3.157895e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 3.289474e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 3.421053e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 3.552632e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 3.684211e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 3.815789e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 3.947368e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 4.078947e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 4.210526e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 4.342105e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 4.473684e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 4.605263e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 4.736842e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 4.868421e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.390000

# %%
# Visualize the cross-validation results
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
# Evaluate the best svm on test set
y_test_pred = best_svm.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('linear SVM on raw pixels final test set accuracy: %f' % test_accuracy)
# Out:
# linear SVM on raw pixels final test set accuracy: 0.376000

# %%
# Visualize the learned weights for each class.
# Depending on your choice of learning rate and regularization strength, these may
# or may not be nice to look at.
w = best_svm.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)
w_min, w_max = np.min(w), np.max(w)
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
      
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])

# %% [markdown]
# ### Inline question 2:
# Describe what your visualized SVM weights look like, and offer a brief explanation for why they look they way that they do.
#
# **Your answer:** *As we can see in the picture.The weights learned by svm is like a blured version of image of that class.It indicates that this kind of weights gives the maximum activation for that class(for example the car weights looks like a red car)*
